# %%
import seaborn as sns
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.corr() 
'''
correltion positive means the two variables are proportional to each other
correlation negative means two variables are inversly proportional to each other
'''
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
sns.jointplot(x="tip", y = "total_bill", data = data, kind = "hex")

# %%
sns.jointplot(x="tip", y = "size", data = data, kind = "reg")

# %%
sns.pairplot(data, hue = "time")

# %%
data["time"].value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
sns.distplot(data["tip"],kde = False, color = "green")
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
'''
Visualization of Cateogerical Data
'''
# Out:
# '\nVisualization of Cateogerical Data\n'

# %%
sns.countplot(y = "day", data = data)
# Out:
# <AxesSubplot:xlabel='count', ylabel='day'>

# %%
sns.barplot(y = "day", x = "total_bill", data = data)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='day'>

# %%
sns.boxplot(x = "day", y = "total_bill", data = data, hue = "smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x = "day", y = "total_bill", data = data, hue = "smoker")
'''
It helps to see both "BOX PLOT" and "KERNEL DENSITY ESTIMATION"
'''
# Out:
# '\nIt helps to see both "BOX PLOT" and "KERNEL DENSITY ESTIMATION"\n'
